# %%
cd /content/drive/MyDrive/yolov7
# Out:
# /content/drive/MyDrive/yolov7

# %%
pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.6 MB/s eta 0:00:00
# ...

# %%
# !python detect_binary.py --weights /content/drive/MyDrive/yolov7/runs/train/yolov7-first-gen-binary/weights/best.pt --conf 0.25 --img-size 640 --source /content/drive/MyDrive/obj/
# Out:
# Namespace(weights=['/content/drive/MyDrive/yolov7/runs/train/yolov7-first-gen-binary/weights/best.pt'], source='/content/drive/MyDrive/obj/', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36487166 parameters, 6194944 gradients, 103.2 GFLOPS
#  Convert model to Traced-model...
# ...

# %%
import matplotlib.pyplot as plt
import cv2
# Set the figure size and spacing
fig = plt.figure(figsize=(20,10))

fig.subplots_adjust(wspace=0.3)

# Create each subplot
ax1 = fig.add_subplot(1, 4, 1)
ax1.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp27/1.JPG'), cv2.COLOR_BGR2RGB))
ax1.axis('off')
ax1.set_title('123 unripes, 1 ripe', fontsize=12)

ax2 = fig.add_subplot(1, 4, 2)
ax2.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp27/2.JPG'), cv2.COLOR_BGR2RGB))
ax2.axis('off')
ax2.set_title('156 unripes, 30 ripes', fontsize=12)

ax3 = fig.add_subplot(1, 4, 3)
ax3.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp27/3.JPG'), cv2.COLOR_BGR2RGB))
ax3.axis('off')
ax3.set_title('192 unripes, 74 ripes', fontsize=12)

ax4 = fig.add_subplot(1, 4, 4)
ax4.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp27/4.jpg'), cv2.COLOR_BGR2RGB))
ax4.axis('off')
ax4.set_title('50 unripes, 165 ripes', fontsize=12)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !python detect_continuous.py --weights /content/drive/MyDrive/yolov7/runs/train/yolov7-first-gen-continuous/weights/best.pt --conf 0.25 --img-size 640 --source /content/drive/MyDrive/obj/
# Out:
# Namespace(weights=['/content/drive/MyDrive/yolov7/runs/train/yolov7-first-gen-continuous/weights/best.pt'], source='/content/drive/MyDrive/obj/', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36503348 parameters, 6194944 gradients, 103.2 GFLOPS
# ...

# %%
import matplotlib.pyplot as plt
import cv2
# Set the figure size and spacing
fig = plt.figure(figsize=(20,40))

fig.subplots_adjust(wspace=0.3)

# Create each subplot
ax1 = fig.add_subplot(1, 4, 1)
ax1.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp29/1.JPG'), cv2.COLOR_BGR2RGB))
ax1.axis('off')
ax1.set_title('1 cherry, 113 green', fontsize=12)

ax2 = fig.add_subplot(1, 4, 2)
ax2.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp29/2.JPG'), cv2.COLOR_BGR2RGB))
ax2.axis('off')
ax2.set_title('8 cherry, 97 green, 53 green_yellow, 13 raisin', fontsize=12)

ax3 = fig.add_subplot(1, 4, 3)
ax3.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp29/3.JPG'), cv2.COLOR_BGR2RGB))
ax3.axis('off')
ax3.set_title('48 cherry, 77 green, 109 green_yellow, 16 raisin', fontsize=12)

ax4 = fig.add_subplot(1, 4, 4)
ax4.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp29/4.jpg'), cv2.COLOR_BGR2RGB))
ax4.axis('off')
ax4.set_title('114 cherry, 50 green_yellow, 47 raisin', fontsize=12)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !python detect_unsup_subc.py --weights runs/train/yolov7-first-gen-5-unsup4/weights/best.pt --conf 0.25 --img-size 640 --source /content/drive/MyDrive/obj/
# Out:
# Namespace(weights=['runs/train/yolov7-first-gen-5-unsup4/weights/best.pt'], source='/content/drive/MyDrive/obj/', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36503348 parameters, 6194944 gradients, 103.2 GFLOPS
#  Convert model to Traced-model...
# ...

# %%
import matplotlib.pyplot as plt
import cv2

# Set the figure size and spacing
fig = plt.figure(figsize=(20,40))
fig.subplots_adjust(wspace=0.3)

# Create each subplot
ax1 = fig.add_subplot(1, 4, 1)
ax1.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp32/1.JPG'), cv2.COLOR_BGR2RGB))
ax1.axis('off')
ax1.set_title(r'$113 \alpha_1, 1 \beta_1, 9 \omega$', fontsize=12)

ax2 = fig.add_subplot(1, 4, 2)
ax2.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp32/2.JPG'), cv2.COLOR_BGR2RGB))
ax2.axis('off')
ax2.set_title(r'$3 \beta_2, 100 \alpha_1, 61 \alpha_2, 23 \beta_1$', fontsize=12)

ax3 = fig.add_subplot(1, 4, 3)
ax3.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp32/3.JPG'), cv2.COLOR_BGR2RGB))
ax3.axis('off')
ax3.set_title(r'$14 \beta_2, 80 \alpha_1, 97 \alpha_2, 91 \beta_1, 2\omega$', fontsize=12)

ax4 = fig.add_subplot(1, 4, 4)
ax4.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp32/4.jpg'), cv2.COLOR_BGR2RGB))
ax4.axis('off')
ax4.set_title(r'$102 \beta_2, 13\alpha_2, 108\beta_1, 4\omega$', fontsize=12)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
cd /content/drive/MyDrive/yolov7
# Out:
# /content/drive/MyDrive/yolov7

# %%
# !python detect_unsup_subc.py --weights runs/train/yolov7-first-gen-5-unsup4/weights/best.pt --conf 0.25 --img-size 640 --source /content/drive/MyDrive/obj/
# Out:
# Namespace(weights=['runs/train/yolov7-first-gen-5-unsup4/weights/best.pt'], source='/content/drive/MyDrive/obj/', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36503348 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
# ...

# %%
encode = {'CO':'beta_2', 'C1':'\alpha_1',
          'C2':'\alpha_2', 'C3': '\beta_1',
          'C4':'\omega'}

# %%
import matplotlib.pyplot as plt
import cv2
# Set the figure size and spacing
fig = plt.figure(figsize=(20,10))

fig.subplots_adjust(wspace=0.3)

# Create each subplot
ax1 = fig.add_subplot(1, 4, 1)
ax1.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp27/1.JPG'), cv2.COLOR_BGR2RGB))
ax1.axis('off')
ax1.set_title('123 unripes, 1 ripe', fontsize=12)

ax2 = fig.add_subplot(1, 4, 2)
ax2.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp27/2.JPG'), cv2.COLOR_BGR2RGB))
ax2.axis('off')
ax2.set_title('156 unripes, 30 ripes', fontsize=12)

ax3 = fig.add_subplot(1, 4, 3)
ax3.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp27/3.JPG'), cv2.COLOR_BGR2RGB))
ax3.axis('off')
ax3.set_title('192 unripes, 74 ripes', fontsize=12)

ax4 = fig.add_subplot(1, 4, 4)
ax4.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp27/4.jpg'), cv2.COLOR_BGR2RGB))
ax4.axis('off')
ax4.set_title('50 unripes, 165 ripes', fontsize=12)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
cd /content/drive/MyDrive/yolov7
# Out:
# /content/drive/MyDrive/yolov7

# %%
# !python detect_binary.py --weights /content/drive/MyDrive/yolov7/runs/train/yolov7-first-gen-binary/weights/best.pt --conf 0.25 --img-size 640 --source /content/drive/MyDrive/obj_new/
# Out:
# Namespace(weights=['/content/drive/MyDrive/yolov7/runs/train/yolov7-first-gen-binary/weights/best.pt'], source='/content/drive/MyDrive/obj_new/', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36487166 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
# ...

# %%
import matplotlib.pyplot as plt
import cv2
# Set the figure size and spacing
fig = plt.figure(figsize=(20,10))

fig.subplots_adjust(wspace=0.3)

# Create each subplot
ax1 = fig.add_subplot(1, 4, 1)
ax1.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp59/new3.jpg'), cv2.COLOR_BGR2RGB))
ax1.axis('off')
ax1.set_title('123 unripes', fontsize=12)

ax2 = fig.add_subplot(1, 4, 2)
ax2.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp59/new_1.jpg'), cv2.COLOR_BGR2RGB))
ax2.axis('off')
ax2.set_title('80 unripes, 27 ripes', fontsize=12)

ax3 = fig.add_subplot(1, 4, 3)
ax3.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp59/new_2.jpg'), cv2.COLOR_BGR2RGB))
ax3.axis('off')
ax3.set_title('80 unripes, 27 ripes', fontsize=12)

ax4 = fig.add_subplot(1, 4, 4)
ax4.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp59/new_4.jpg'), cv2.COLOR_BGR2RGB))
ax4.axis('off')
ax4.set_title('59 unripes, 1 ripe', fontsize=12)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !python detect_continuous.py --weights /content/drive/MyDrive/yolov7/runs/train/yolov7-first-gen-continuous/weights/best.pt --conf 0.25 --img-size 640 --source /content/drive/MyDrive/obj_new/
# Out:
# Namespace(weights=['/content/drive/MyDrive/yolov7/runs/train/yolov7-first-gen-continuous/weights/best.pt'], source='/content/drive/MyDrive/obj_new/', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36503348 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
# ...

# %%
import matplotlib.pyplot as plt
import cv2
# Set the figure size and spacing
fig = plt.figure(figsize=(20,10))

fig.subplots_adjust(wspace=0.3)

# Create each subplot
ax1 = fig.add_subplot(1, 4, 1)
ax1.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp60/new3.jpg'), cv2.COLOR_BGR2RGB))
ax1.axis('off')
ax1.set_title('120 greens, 24 green_yellows', fontsize=12)

ax2 = fig.add_subplot(1, 4, 2)
ax2.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp60/new_1.jpg'), cv2.COLOR_BGR2RGB))
ax2.axis('off')
ax2.set_title('13 cherrys, 28 greens, 39 green_yellows, 11 raisins,', fontsize=12)

ax3 = fig.add_subplot(1, 4, 3)
ax3.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp60/new_2.jpg'), cv2.COLOR_BGR2RGB))
ax3.axis('off')
ax3.set_title('9 cherrys, 186 greens, 44 green_yellows, 1 raisin', fontsize=12)

ax4 = fig.add_subplot(1, 4, 4)
ax4.imshow(cv2.cvtColor(cv2.imread('runs/detect/exp60/new_4.jpg'), cv2.COLOR_BGR2RGB))
ax4.axis('off')
ax4.set_title('1 cherry, 59 greens, 18 green_yellows, 1 raisin', fontsize=12)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
