# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
mkdir coffe_fruits_scale && mkdir coffe_fruits_scale/fruits && mkdir coffe_fruits_scale/annotations/

# %%
annotations_folder = '/content/drive/MyDrive/coffe_fruits_scale/annotations'
fruits_folder = '/content/drive/MyDrive/coffe_fruits_scale/fruits'

# %%
cd /content/drive/MyDrive/yolov7
# Out:
# /content/drive/MyDrive/yolov7

# %%
# !python _sampler.py --weights /content/drive/MyDrive/yolov7/runs/train/yolov7-first-gen-mono/weights/best.pt --conf 0.5 --img-size 640 --source /content/drive/MyDrive/coffeAI-detector-first-gen/images
# Out:
# Namespace(weights=['/content/drive/MyDrive/yolov7/runs/train/yolov7-first-gen-mono/weights/best.pt'], source='/content/drive/MyDrive/coffeAI-detector-first-gen/images', img_size=640, conf_thres=0.5, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...
